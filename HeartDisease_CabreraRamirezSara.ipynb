# %% [markdown]
# # **Personal Key Indicators of Heart Disease**

# %% [markdown]
# Link zum Kaggle Dataset: https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease

# %% [markdown]
# ## **Imports**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Daten einlesen**

# %%
df = pd.read_csv("drive/MyDrive/heart_2020_cleaned.csv")

# %% [markdown]
# ## **Daten analysieren**

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
df.tail(10)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319785           No  31.93      No             Yes     No             0.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319787           No  36.54      No              No     No             7.0
# 319788           No  23.38      No              No     No             0.0
# 319789           No  22.22      No              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319785           0.0          No    Male        65-69  Hispanic       No
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# Nur columns angezeigt mit dem Datentyp float

# %% [markdown]
# Interessante Daten:
#
# ---
#
#
#
# *   Durchschnittlicher BMI = 28.33
# *   Schlechter physischer Zustand/30t. = 3.7 t
# *   Schlechter mentaler Zustand/30t. = 3.9 t
# *   Durchschnittliche Stunden Schlaf = 7.1 h

# %%
df.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
df['BMI'].unique()
# Out:
# array([16.6 , 20.34, 26.58, ..., 62.42, 51.46, 46.56])

# %%
df['AgeCategory'].unique()
# Out:
# array(['55-59', '80 or older', '65-69', '75-79', '40-44', '70-74',
#        '60-64', '50-54', '45-49', '18-24', '35-39', '30-34', '25-29'],
#       dtype=object)

# %%
df['AlcoholDrinking'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Race'].unique()
# Out:
# array(['White', 'Black', 'Asian', 'American Indian/Alaskan Native',
#        'Other', 'Hispanic'], dtype=object)

# %%
columns = df.columns
for column in columns:
    print(column,df[column].unique())
# Out:
# HeartDisease ['No' 'Yes']
# BMI [16.6  20.34 26.58 ... 62.42 51.46 46.56]
# Smoking ['Yes' 'No']
# AlcoholDrinking ['No' 'Yes']
# Stroke ['No' 'Yes']
# PhysicalHealth [ 3.  0. 20. 28.  6. 15.  5. 30.  7.  1.  2. 21.  4. 10. 14. 18.  8. 25.
#  16. 29. 27. 17. 24. 12. 23. 26. 22. 19.  9. 13. 11.]
# MentalHealth [30.  0.  2.  5. 15.  8.  4.  3. 10. 14. 20.  1.  7. 24.  9. 28. 16. 12.
#   6. 25. 17. 18. 21. 29. 22. 13. 23. 27. 26. 11. 19.]
# DiffWalking ['No' 'Yes']
# Sex ['Female' 'Male']
# AgeCategory ['55-59' '80 or older' '65-69' '75-79' '40-44' '70-74' '60-64' '50-54'
#  '45-49' '18-24' '35-39' '30-34' '25-29']
# Race ['White' 'Black' 'Asian' 'American Indian/Alaskan Native' 'Other'
#  'Hispanic']
# Diabetic ['Yes' 'No' 'No, borderline diabetes' 'Yes (during pregnancy)']
# PhysicalActivity ['Yes' 'No']
# GenHealth ['Very good' 'Fair' 'Good' 'Poor' 'Excellent']
# SleepTime [ 5.  7.  8.  6. 12.  4.  9. 10. 15.  3.  2.  1. 16. 18. 14. 20. 11. 13.
#  17. 24. 19. 21. 22. 23.]
# ...

# %% [markdown]
# ## **Dataset säubern**

# %%
df.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.isnull().any()
# Out:
# HeartDisease        False
# BMI                 False
# Smoking             False
# AlcoholDrinking     False
# Stroke              False
# PhysicalHealth      False
# MentalHealth        False
# DiffWalking         False
# Sex                 False
# AgeCategory         False
# Race                False
# Diabetic            False
# PhysicalActivity    False
# GenHealth           False
# SleepTime           False
# Asthma              False
# KidneyDisease       False
# SkinCancer          False
# dtype: bool

# %% [markdown]
# Keine leeren Datensätze

# %%
heart = df.drop(['Race', 'GenHealth', 'Stroke', 'DiffWalking'], axis=1)

# %%
heart.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking  PhysicalHealth  MentalHealth  \
# 0           No  16.60     Yes              No             3.0          30.0
# 1           No  20.34      No              No             0.0           0.0
# 2           No  26.58     Yes              No            20.0          30.0
# 3           No  24.21      No              No             0.0           0.0
# 4           No  23.71      No              No            28.0           0.0
#
#       Sex  AgeCategory Diabetic PhysicalActivity  SleepTime Asthma  \
# 0  Female        55-59      Yes              Yes        5.0    Yes
# 1  Female  80 or older       No              Yes        7.0     No
# 2    Male        65-69      Yes              Yes        8.0    Yes
# 3  Female        75-79       No               No        6.0     No
# 4  Female        40-44       No              Yes        8.0     No
#
#   KidneyDisease SkinCancer
# 0            No        Yes
# 1            No         No
# ...

# %% [markdown]
# 'Yes' zu 1 umwandeln und 'No' zu 0

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder() 
heart['Smoking'] = lb.fit_transform(heart['Smoking'])

# %%
lb = LabelEncoder() 
heart['HeartDisease'] = lb.fit_transform(heart['HeartDisease'])

# %%
lb = LabelEncoder() 
heart['AlcoholDrinking'] = lb.fit_transform(heart['AlcoholDrinking'])

# %%
lb = LabelEncoder() 
heart['KidneyDisease'] = lb.fit_transform(heart['KidneyDisease'])

# %%
lb = LabelEncoder() 
heart['SkinCancer'] = lb.fit_transform(heart['SkinCancer'])

# %%
lb = LabelEncoder() 
heart['PhysicalActivity'] = lb.fit_transform(heart['PhysicalActivity'])

# %%
lb = LabelEncoder() 
heart['Asthma'] = lb.fit_transform(heart['Asthma'])

# %%
lb = LabelEncoder() 
heart['Diabetic'] = lb.fit_transform(heart['Diabetic'])

# %%
lb = LabelEncoder() 
heart['Sex'] = lb.fit_transform(heart['Sex'])

# %%
def convert_AgeCategory(heart):
    severity_dict = {"18-24": 1, "25-29":2,"30-34":3,"35-39":4, "40-44" :5, "45-49": 6, "50-54": 7, "55-59": 8, "60-64":9, "65-69":10, "70-74":11, "75-79":12, "80 or older":13}
    heart = heart.replace({"AgeCategory":severity_dict})
    return heart

heart = convert_AgeCategory(heart)

# %%
print(heart)
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 0                  0  16.60        1                0             3.0
# 1                  0  20.34        0                0             0.0
# 2                  0  26.58        1                0            20.0
# 3                  0  24.21        0                0             0.0
# 4                  0  23.71        0                0            28.0
# ...              ...    ...      ...              ...             ...
# 319790             1  27.41        1                0             7.0
# 319791             0  29.84        1                0             0.0
# 319792             0  24.24        0                0             0.0
# 319793             0  32.81        0                0             0.0
# 319794             0  46.56        0                0             0.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %% [markdown]
# ### **Duplikate löschen**

# %%
heart[heart.duplicated() == True]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 1099               0  30.90        0                0             0.0
# 2055               0  25.85        1                0             0.0
# 2182               0  19.85        0                0             0.0
# 2566               0  25.75        0                0             0.0
# 3182               0  28.19        0                0             0.0
# ...              ...    ...      ...              ...             ...
# 319776             0  27.98        0                0             0.0
# 319778             0  26.63        0                0             0.0
# 319783             0  33.28        0                0             0.0
# 319784             0  26.58        1                0             0.0
# 319788             0  23.38        0                0             0.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %%
heart.drop_duplicates()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 0                  0  16.60        1                0             3.0
# 1                  0  20.34        0                0             0.0
# 2                  0  26.58        1                0            20.0
# 3                  0  24.21        0                0             0.0
# 4                  0  23.71        0                0            28.0
# ...              ...    ...      ...              ...             ...
# 319790             1  27.41        1                0             7.0
# 319791             0  29.84        1                0             0.0
# 319792             0  24.24        0                0             0.0
# 319793             0  32.81        0                0             0.0
# 319794             0  46.56        0                0             0.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %% [markdown]
# ## **Beziehungen analysieren**

# %%
import plotly.express as px

# %%
correlation = heart.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)

# %%
sns.countplot(x="HeartDisease", data=heart)
plt.show()

# %%
heart.describe()
# Out:
#         HeartDisease            BMI        Smoking  AlcoholDrinking  \
# count  319795.000000  319795.000000  319795.000000    319795.000000
# mean        0.085595      28.325399       0.412477         0.068097
# std         0.279766       6.356100       0.492281         0.251912
# min         0.000000      12.020000       0.000000         0.000000
# 25%         0.000000      24.030000       0.000000         0.000000
# 50%         0.000000      27.340000       0.000000         0.000000
# 75%         0.000000      31.420000       1.000000         0.000000
# max         1.000000      94.850000       1.000000         1.000000
#
#        PhysicalHealth   MentalHealth            Sex       Diabetic  \
# count    319795.00000  319795.000000  319795.000000  319795.000000
# mean          3.37171       3.898366       0.475273       0.300386
# std           7.95085       7.955235       0.499389       0.716480
# min           0.00000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# Korrelation BMI - Herzerkrankung

# %%
cond1 = heart['BMI'] >= 25
cond2 = heart['HeartDisease'] == 1
bmihd = cond1 & cond2
heart[bmihd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 5                  1  28.87        1                0             6.0
# 10                 1  34.30        1                0            30.0
# 35                 1  32.98        1                0            10.0
# 42                 1  25.06        0                0             0.0
# 43                 1  30.23        1                0             6.0
# ...              ...    ...      ...              ...             ...
# 319765             1  38.45        0                0            30.0
# 319767             1  36.21        1                0             0.0
# 319781             1  37.12        1                0             0.0
# 319786             1  33.20        1                0             0.0
# 319790             1  27.41        1                0             7.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %% [markdown]
# Korrelation Herzerkrankung - Alterskategorie

# %%
heart['AgeCategory'].value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
cond8 = heart['AgeCategory'] >= 8
ahd = cond2 & cond8
heart[ahd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 5                  1  28.87        1                0             6.0
# 10                 1  34.30        1                0            30.0
# 35                 1  32.98        1                0            10.0
# 42                 1  25.06        0                0             0.0
# 43                 1  30.23        1                0             6.0
# ...              ...    ...      ...              ...             ...
# 319758             1  28.32        1                0             0.0
# 319765             1  38.45        0                0            30.0
# 319767             1  36.21        1                0             0.0
# 319786             1  33.20        1                0             0.0
# 319790             1  27.41        1                0             7.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %%
sns.countplot(data=heart, x="AgeCategory", hue="HeartDisease")

# %% [markdown]
# Korrelation Herzerkrankung - Nierenkrankheit

# %%
sns.countplot(data=heart, x='HeartDisease', hue="KidneyDisease")

# %%
cond6 = heart['KidneyDisease'] == 1
khd = cond2 & cond6
heart[khd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 43                 1  30.23        1                0             6.0
# 78                 1  28.29        1                0            30.0
# 149                1  23.34        0                0             0.0
# 184                1  25.80        1                0             7.0
# 217                1  28.41        1                0            10.0
# ...              ...    ...      ...              ...             ...
# 319619             1  39.31        0                0             3.0
# 319620             1  27.64        0                0             1.0
# 319708             1  24.41        1                0            15.0
# 319721             1  39.30        0                0            30.0
# 319739             1  35.02        0                0            15.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %%
cond7 = heart['HeartDisease'] == 0
knhd = cond6 & cond7
heart[knhd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 8                  0  26.45        0                0             0.0
# 18                 0  29.86        1                0             0.0
# 39                 0  21.93        0                0             3.0
# 65                 0  26.63        0                0            20.0
# 66                 0  34.01        1                0            14.0
# ...              ...    ...      ...              ...             ...
# 319699             0  27.46        1                1             0.0
# 319735             0  31.44        0                0            10.0
# 319738             0  37.59        1                0             0.0
# 319745             0  22.83        0                0             3.0
# 319759             0  26.63        0                0             0.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %% [markdown]
# Korrelation Herzerkrankung - Alkohol, etc.

# %%
sns.countplot(data=heart, x='HeartDisease', hue="Diabetic")

# %%
sns.countplot(data=heart, x='HeartDisease', hue="Asthma")

# %%
sns.countplot(data=heart, x='HeartDisease', hue="KidneyDisease")

# %%
sns.countplot(data=heart, x='HeartDisease', hue="AlcoholDrinking")

# %%
sns.countplot(data=heart, x='HeartDisease', hue="Smoking")

# %%
cond3 = heart['AlcoholDrinking'] == 1
alchd = cond2 & cond3

heart[alchd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 142                1  31.48        0                1            20.0
# 396                1  26.96        1                1             0.0
# 807                1  24.94        1                1             0.0
# 831                1  21.80        1                1             0.0
# 1353               1  28.89        0                1             0.0
# ...              ...    ...      ...              ...             ...
# 317195             1  33.77        1                1             0.0
# 318683             1  30.40        1                1             0.0
# 318821             1  40.23        0                1             0.0
# 319513             1  35.62        0                1             0.0
# 319601             1  30.19        1                1            30.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %% [markdown]
# Korrelation Herzerkrankung - Rauchen

# %%
cond4 = heart['Smoking'] == 1
smhd = cond2 & cond4
heart[smhd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 5                  1  28.87        1                0             6.0
# 10                 1  34.30        1                0            30.0
# 35                 1  32.98        1                0            10.0
# 43                 1  30.23        1                0             6.0
# 45                 1  20.37        1                0             3.0
# ...              ...    ...      ...              ...             ...
# 319758             1  28.32        1                0             0.0
# 319767             1  36.21        1                0             0.0
# 319781             1  37.12        1                0             0.0
# 319786             1  33.20        1                0             0.0
# 319790             1  27.41        1                0             7.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %%
heart.shape
# Out:
# (319795, 14)

# %% [markdown]
# Sind Männer eher inkliniert eine Herzerkrankung zu haben?

# %%
cond5 = heart['Sex'] == 1 #Male
mlhd = cond2 & cond5
heart[mlhd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 10                 1  34.30        1                0            30.0
# 35                 1  32.98        1                0            10.0
# 101                1  24.68        1                0            30.0
# 140                1  23.73        0                0             0.0
# 142                1  31.48        0                1            20.0
# ...              ...    ...      ...              ...             ...
# 319708             1  24.41        1                0            15.0
# 319739             1  35.02        0                0            15.0
# 319761             1  29.43        0                0             7.0
# 319781             1  37.12        1                0             0.0
# 319790             1  27.41        1                0             7.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %%
fig, ax = plt.subplots(figsize = (10,6))

ax.hist(heart[heart["HeartDisease"]==0]["Sex"], bins=3, alpha=0.8, color="#59966c", label="No HeartDisease")
ax.hist(heart[heart["HeartDisease"]==1]["Sex"], bins=3, alpha=1, color="#e394a7", label="HeartDisease")

ax.set_xlabel("Sex")
ax.set_ylabel("Amount of people")

ax.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)

# %%
cond6 = heart['Sex'] == 0 #Female
flhd = cond2 & cond6
heart[flhd]
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  PhysicalHealth  \
# 5                  1  28.87        1                0             6.0
# 42                 1  25.06        0                0             0.0
# 43                 1  30.23        1                0             6.0
# 45                 1  20.37        1                0             3.0
# 77                 1  34.33        0                0             0.0
# ...              ...    ...      ...              ...             ...
# 319721             1  39.30        0                0            30.0
# 319758             1  28.32        1                0             0.0
# 319765             1  38.45        0                0            30.0
# 319767             1  36.21        1                0             0.0
# 319786             1  33.20        1                0             0.0
#
#         MentalHealth  Sex  AgeCategory  Diabetic  PhysicalActivity  SleepTime  \
# ...

# %% [markdown]
# ## **Splitting / Klassifizierung**

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
X, Y = heart.iloc[:, 1:], heart.iloc[:, :1]

# %%
X.head()
# Out:
#      BMI  Smoking  AlcoholDrinking  PhysicalHealth  MentalHealth  Sex  \
# 0  16.60        1                0             3.0          30.0    0
# 1  20.34        0                0             0.0           0.0    0
# 2  26.58        1                0            20.0          30.0    1
# 3  24.21        0                0             0.0           0.0    0
# 4  23.71        0                0            28.0           0.0    0
#
#    AgeCategory  Diabetic  PhysicalActivity  SleepTime  Asthma  KidneyDisease  \
# 0            8         2                 1        5.0       1              0
# 1           13         0                 1        7.0       0              0
# 2           10         2                 1        8.0       1              0
# 3           12         0                 0        6.0       0              0
# 4            5         0                 1        8.0       0              0
#
#    SkinCancer
# 0           1
# 1           0
# 2           0
# 3           1
# ...

# %%
Y.head()
# Out:
#    HeartDisease
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(Y.values.ravel())
# Out:
# LabelEncoder()

# %%
y_transformed = le.transform(Y.values.ravel())

# %%
y_transformed
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, y_transformed, test_size=0.3)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train, Y_train)

# %%
y_pred = clf.predict(X_test)

# %%
y_pred

# %%
print("Genauigkeit:", accuracy_score(Y_test, y_pred))
# Out:
# Genauigkeit: 0.8628190829589635

# %% [markdown]
# Genauigkeit war zu 86%

# %%
num_folds = 7 #folds = Versuche
num_instances = len(X_train)
seed = 7
scoring ='accuracy'

# %%
models =  []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier(n_neighbors=5)))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))

# %%
results = []
names = []
for name, model in models:
  kfold = KFold(n_splits=num_folds)
  cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring = scoring)
  results.append(cv_results)
  names.append(name)
  msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std() * 100)
  print(msg)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
